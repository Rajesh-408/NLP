# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import lxml
from lxml import html

# %%
def parse_url(web_link):
    response = requests.get(web_link)
    tree = lxml.html.fromstring(response.text)
    #links = tree.cssselect('a')  # or tree.xpath('//a')
    links=tree.xpath('//a')
    return links

def scrape_data(links):
    final_df=pd.DataFrame()
    for link in links:
        if 'href' in link.attrib:
            term_link = link.attrib['href']
            internal_web_link=web_search(term_link)
            if internal_web_link:
                term_text=benefit_name_search(internal_web_link)
                #internal_web_link='https://www.healthcare.gov/glossary/abortion-services/'
                print(internal_web_link)
                try:
                    response = requests.get(internal_web_link)
                    tree_2 = lxml.html.fromstring(response.text)
                    links_2=tree_2.xpath(x_path_web)
                    for linkup in links_2:
                        description = ' '.join(linkup.xpath('.//p//text()')).strip()
                        print("Benefit_name",term_text)
                        print("Web_link",internal_web_link)
                        out_df=pd.DataFrame({"Benefit_name":term_text,
                                         "Web_link":internal_web_link,
                                         "Description":description},index=[0])
                        final_df=final_df.append(out_df)
                except Exception as e:
                    continue
    final_df.reset_index(inplace=True,drop=True)
    return final_df

def web_search(href_link):
    try:
        internal_web_link=url.rsplit('/',2)[0]+href_link
        response = requests.get(internal_web_link)
        if response.status_code == 200:
            return internal_web_link
        
    except Exception as e:
        internal_web_link=url.rsplit('/',1)[0]+href_link
        response = requests.get(internal_web_link)
        if response.status_code == 200:
            return internal_web_link

def benefit_name_search(internal_web_link):
    term_text=internal_web_link.rsplit('/')[-1]
    if term_text=='':
        term_text=internal_web_link.rsplit('/')[-2]
    else:
        term_text
    return term_text

def save_to_excel(dataframe):
    df = dataframe.copy()
    #data = df.groupby(['Benefit_name', 'Web_link'])['Description'].sum()
    #data=data.to_frame()
    pd.set_option('display.max_colwidth', None)
    df.to_excel('C:\Documents\Benefit_descriptions\Benefit_description_long.xlsx')
    print("Saved file in Path")

# %%
url='https://www.insuranceopedia.com/dictionary'
x_path_web = "/html/body/main/div/div/article/div[3]"

# %%
Parsing_data=parse_url(url)

# %%
scrapping_data=scrape_data(Parsing_data)
# Out:
# https://www.insuranceopedia.com/
# https://www.insuranceopedia.com/life-insurance-quote?utm_source=insuranceopedia&utm_medium=nav
# https://www.insuranceopedia.com/car-insurance-comparison?utm_source=insuranceopedia&utm_medium=nav
# https://www.insuranceopedia.com/dictionary
# https://www.insuranceopedia.com/dictionary
# https://www.insuranceopedia.com/definition/1244/combined-single-limit
# Benefit_name combined-single-limit
# Web_link https://www.insuranceopedia.com/definition/1244/combined-single-limit
# https://www.insuranceopedia.com/definition/1244/combined-single-limit
# Benefit_name combined-single-limit
# Web_link https://www.insuranceopedia.com/definition/1244/combined-single-limit
# https://www.insuranceopedia.com/definition/5501/durable-medical-equipment-dme
# Benefit_name durable-medical-equipment-dme
# Web_link https://www.insuranceopedia.com/definition/5501/durable-medical-equipment-dme
# https://www.insuranceopedia.com/definition/459/principle-of-indemnity
# Benefit_name principle-of-indemnity
# Web_link https://www.insuranceopedia.com/definition/459/principle-of-indemnity
# https://www.insuranceopedia.com/definition/4022/risk-retention
# Benefit_name risk-retention
# Web_link https://www.insuranceopedia.com/definition/4022/risk-retention
# https://www.insuranceopedia.com/definition/5228/free-consent
# Benefit_name free-consent
# Web_link https://www.insuranceopedia.com/definition/5228/free-consent
# https://www.insuranceopedia.com/definition/377/in-force
# Benefit_name in-force
# Web_link https://www.insuranceopedia.com/definition/377/in-force
# https://www.insuranceopedia.com/definition/1679/elements-of-an-insurance-contract
# Benefit_name elements-of-an-insurance-contract
# Web_link https://www.insuranceopedia.com/definition/1679/elements-of-an-insurance-contract
# https://www.insuranceopedia.com/2/5207/the-insurance-business/a-look-at-uninsurable-risk
# https://www.insuranceopedia.com/2/5207/the-insurance-business/a-look-at-uninsurable-risk
# https://www.insuranceopedia.com/2/5059/property-insurance/homeowners-insurance/insurance-agents-whats-the-point
# https://www.insuranceopedia.com/2/5059/property-insurance/homeowners-insurance/insurance-agents-whats-the-point
# https://www.insuranceopedia.com/2/5052/life-insurance/the-perfect-age-to-get-life-insurance
# https://www.insuranceopedia.com/2/5052/life-insurance/the-perfect-age-to-get-life-insurance
# https://www.insuranceopedia.com/cobra-insurance-what-it-is-and-if-its-right-for-you/2/5993
# https://www.insuranceopedia.com/cobra-insurance-what-it-is-and-if-its-right-for-you/2/5993
# https://www.insuranceopedia.com/4-types-of-liability-insurance-every-business-should-have/2/5177
# https://www.insuranceopedia.com/4-types-of-liability-insurance-every-business-should-have/2/5177
# https://www.insuranceopedia.com/2/5059/property-insurance/homeowners-insurance/insurance-agents-whats-the-point
# https://www.insuranceopedia.com/2/5059/property-insurance/homeowners-insurance/insurance-agents-whats-the-point
# https://www.insuranceopedia.com/etsy-for-sellers-what-insurance-do-you-need/2/5667
# https://www.insuranceopedia.com/etsy-for-sellers-what-insurance-do-you-need/2/5667
# https://www.insuranceopedia.com/the-6-types-of-business-insurance-many-companies-dont-realize-they-need/2/5765
# https://www.insuranceopedia.com/the-6-types-of-business-insurance-many-companies-dont-realize-they-need/2/5765
# https://www.insuranceopedia.com/important-insurance-coverage-for-seniors/2/5749
# https://www.insuranceopedia.com/important-insurance-coverage-for-seniors/2/5749
# https://www.insuranceopedia.com/what-canadians-need-to-understand-about-their-travel-insurance/2/5931
# https://www.insuranceopedia.com/what-canadians-need-to-understand-about-their-travel-insurance/2/5931
# https://www.insuranceopedia.com/2/4995/coverage/9-insurance-perks-your-credit-card-provider-might-offer
# https://www.insuranceopedia.com/2/4995/coverage/9-insurance-perks-your-credit-card-provider-might-offer
# https://www.insuranceopedia.com/2/5247/international-insurance/travel-insurance-do-i-really-have-to
# https://www.insuranceopedia.com/2/5247/international-insurance/travel-insurance-do-i-really-have-to
# https://www.insuranceopedia.com/experts
# https://www.insuranceopedia.com#
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5696/2110929095.py in web_search(href_link)
#      37         internal_web_link=url.rsplit('/',2)[0]+href_link
# ---> 38         response = requests.get(internal_web_link)
#      39         if response.status_code == 200:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     315         self.prepare_method(method)
# --> 316         self.prepare_url(url, params)
#     317         self.prepare_headers(headers)
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     392         if not host:
# --> 393             raise InvalidURL("Invalid URL %r: No host supplied" % url)
#     394
#
# InvalidURL: Invalid URL 'https:/https://www.facebook.com/insuranceopedia': No host supplied
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000024B05D4B100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='www.insuranceopedia.comhttps', port=443): Max retries exceeded with url: //www.facebook.com/insuranceopedia (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024B05D4B100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5696/380448794.py in <module>
# ----> 1 scrapping_data=scrape_data(Parsing_data)
#
# ~\AppData\Local\Temp/ipykernel_5696/2110929095.py in scrape_data(links)
#      11         if 'href' in link.attrib:
#      12             term_link = link.attrib['href']
# ---> 13             internal_web_link=web_search(term_link)
#      14             if internal_web_link:
#      15                 term_text=benefit_name_search(internal_web_link)
#
# ~\AppData\Local\Temp/ipykernel_5696/2110929095.py in web_search(href_link)
#      42     except Exception as e:
#      43         internal_web_link=url.rsplit('/',1)[0]+href_link
# ---> 44         response = requests.get(internal_web_link)
#      45         if response.status_code == 200:
#      46             return internal_web_link
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.insuranceopedia.comhttps', port=443): Max retries exceeded with url: //www.facebook.com/insuranceopedia (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024B05D4B100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
description = ' '.join(linkup.xpath('.//p//text()').strip()
text_content = ' '.join(linkup.xpath('.//p//text()')).strip()
